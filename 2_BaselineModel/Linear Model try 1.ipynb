# %%
# %pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.14.5)
# Requirement already satisfied: numpy<3,>=1.22.3 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (2.3.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (1.16.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.formula.api as smf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Trainingsdaten laden
train_data = pd.read_csv('../0_DataPreparation/data/train_data.csv')

# Modell trainieren
mod = smf.ols('Umsatz ~ C(Warengruppe)', data=train_data).fit()
print(mod.summary())

# Test-/Vorhersagedaten laden (die 1830 Zeilen ohne Umsatz)
test_data = pd.read_csv('../0_DataPreparation/data/test_data.csv')  

# Vorhersagen machen
test_data['Umsatz_Vorhersage'] = mod.predict(test_data)

# Nur ID und Umsatz_Vorhersage speichern
predictions_output = test_data[['id', 'Umsatz_Vorhersage']]
predictions_output.to_csv('../0_DataPreparation/data/predictions.csv', index=False)

# Erste Vorhersagen anzeigen
print("\nErste 10 Vorhersagen:")
print(predictions_output.head(10))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Umsatz   R-squared:                       0.651
# Model:                            OLS   Adj. R-squared:                  0.650
# Method:                 Least Squares   F-statistic:                     2788.
# Date:                Thu, 27 Nov 2025   Prob (F-statistic):               0.00
# Time:                        16:26:40   Log-Likelihood:                -44125.
# No. Observations:                7493   AIC:                         8.826e+04
# Df Residuals:                    7487   BIC:                         8.830e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept             121.3353      2.285     53.094      0.000     116.855     125.815
# C(Warengruppe)[T.2]   289.2590      3.232     89.501      0.000     282.924     295.594
# C(Warengruppe)[T.3]    42.8076      3.232     13.245      0.000      36.472      49.143
# C(Warengruppe)[T.4]   -33.0088      3.262    -10.119      0.000     -39.404     -26.614
# C(Warengruppe)[T.5]   159.5546      3.232     49.369      0.000     153.219     165.890
# C(Warengruppe)[T.6]   -54.3611      6.130     -8.868      0.000     -66.378     -42.345
# ==============================================================================
# Omnibus:                     6535.130   Durbin-Watson:                   1.345
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           769298.986
# Skew:                           3.642   Prob(JB):                         0.00
# Kurtosis:                      52.102   Cond. No.                         7.24
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Erste 10 Vorhersagen:
#         id  Umsatz_Vorhersage
# 0  1808015         280.889924
# 1  1808012         410.594284
# 2  1808013         164.142961
# 3  1808014          88.326489
# 4  1808011         121.335322
# 5  1808023         164.142961
# 6  1808025         280.889924
# 7  1808022         410.594284
# 8  1808021         121.335322
# 9  1808024          88.326489

# %% [markdown]
# #### r^2 berechnen
#
# rse = sum (errors^2)/sum((actual-mean(actual))^2)
# r^2 = 1-rse

# %%
## mehrere Variablen

# Trainingsdaten laden
train_data = pd.read_csv('../0_DataPreparation/data/train_data.csv')


# Modell trainieren
mod = smf.ols('Umsatz ~ Temperatur + Windgeschwindigkeit + KielerWoche + Feiertage + WetterDurchgehenderLeichter_Regen + WetterDurchgehenderMässigerRegen + WetterDurchgehenderStarkerRegen + WetterDurchgehenderleichterSchneefall + WetterDurchgehendermaessigerSchneefall + WetterFeuchterDunst + WetterGewitter + WetterKlar + WetterNebel + WetterNebelReifansatz + WetterNebelaufgehoert + WetterRegenaufgehoert + Wetter_Schnee_aufgehoert + WetterSchneegriesel + WetterSonstige + WetterSpuehregenoderSchneegrieselaufgehoert + WetterTrockenerDunst + WetterandauernderSpruehregen + WarengruppeBread + WarengruppeRolls + WarengruppeCroissants + WarengruppeConfectionery + WarengruppeCake + WarengruppeSeasonalBread + Montag + Dienstag + Mittwoch + Donnerstag + Freitag + Samstag + Sonntag + Januar + Februar + Maerz + April + Mai + Juni + Juli + August + September + Oktober + November + Dezember + Bewoelkung08Klar + Bewoelkung18Fastwolkenlos + Bewoelkung28leichtbewoelkt + Bewoelkung38 + Bewoelkung48wolkig + Bewoelkung58 + Bewoelkung68starkbewoelkt + Bewoelkung78fastbedeckt + Bewoelkung88bedeckt',
               data=train_data).fit()
print(mod.summary())

# Test-/Vorhersagedaten laden (die 1830 Zeilen ohne Umsatz)
test_data = pd.read_csv('../0_DataPreparation/data/test_data.csv')  

# Vorhersagen machen
test_data['Umsatz_Vorhersage'] = mod.predict(test_data)

# Nur ID und Umsatz_Vorhersage speichern
predictions_output = test_data[['id', 'Umsatz_Vorhersage']]
predictions_output.to_csv('../0_DataPreparation/data/predictions_preencoded.csv', index=False)

# Erste Vorhersagen anzeigen
print("\nErste 10 Vorhersagen:")
print(predictions_output.head(10))

#print("Warengruppe Dummy-Spalten:", warengruppe_cols)
#print("Wetter Dummy-Spalten:", wetter_cols)
#print("Bewoelkung Dummy-Spalten:", bewoelkung_cols)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Umsatz   R-squared:                       0.740
# Model:                            OLS   Adj. R-squared:                  0.738
# Method:                 Least Squares   F-statistic:                     375.1
# Date:                Thu, 11 Dec 2025   Prob (F-statistic):               0.00
# Time:                        16:17:19   Log-Likelihood:                -42588.
# No. Observations:                7422   AIC:                         8.529e+04
# Df Residuals:                    7365   BIC:                         8.568e+04
# Df Model:                          56
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                     124.4810      3.289     37.847      0.000     118.033     130.929
# Feiertage[T.Christi Himmelfahrt]               62.7048     17.427      3.598      0.000      28.542      96.867
# Feiertage[T.Erster Mai]                        12.8157     34.115      0.376      0.707     -54.059      79.690
# Feiertage[T.Ostermontag]                       86.6333     17.259      5.020      0.000      52.801     120.466
# Feiertage[T.Pfingstmontag]                    116.9597     17.230      6.788      0.000      83.184     150.735
# Feiertage[T.Tag der Deutschen Einheit]         53.0131     17.269      3.070      0.002      19.160      86.866
# Temperatur                                      0.3296      0.296      1.114      0.265      -0.251       0.910
# Windgeschwindigkeit                             0.3120      0.228      1.368      0.171      -0.135       0.759
# KielerWoche                                    39.3595      6.863      5.735      0.000      25.907      52.812
# WetterDurchgehenderLeichter_Regen              -5.0407      3.027     -1.665      0.096     -10.975       0.893
# WetterDurchgehenderMässigerRegen               -5.3651      4.260     -1.259      0.208     -13.716       2.986
# WetterDurchgehenderStarkerRegen                -4.0650      8.105     -0.502      0.616     -19.952      11.822
# WetterDurchgehenderleichterSchneefall          -8.5661     13.065     -0.656      0.512     -34.178      17.046
# WetterDurchgehendermaessigerSchneefall        -33.0754     18.759     -1.763      0.078     -69.849       3.698
# WetterFeuchterDunst                            -0.5118      3.932     -0.130      0.896      -8.219       7.195
# WetterGewitter                                 -5.6953      7.577     -0.752      0.452     -20.549       9.158
# WetterKlar                                     -6.3687      3.542     -1.798      0.072     -13.312       0.575
# WetterNebel                                   -13.2789      8.931     -1.487      0.137     -30.787       4.229
# WetterNebelReifansatz                         -20.0478     12.096     -1.657      0.097     -43.760       3.665
# WetterNebelaufgehoert                          32.2693     10.326      3.125      0.002      12.028      52.511
# WetterRegenaufgehoert                          -6.3884      3.384     -1.888      0.059     -13.022       0.245
# Wetter_Schnee_aufgehoert                        0.8475     10.600      0.080      0.936     -19.932      21.627
# WetterSchneegriesel                            -0.6606     13.435     -0.049      0.961     -26.997      25.676
# WetterSonstige                                 -3.7962     12.232     -0.310      0.756     -27.775      20.183
