# %%
# Installieren und Importieren der notwendigen Module

# %pip install statsmodels
import statsmodels.formula.api as smf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
# Out:
# Requirement already satisfied: statsmodels in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.14.5)
# Requirement already satisfied: numpy<3,>=1.22.3 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (2.3.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (1.16.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Trainings-, Validierungs- und Testdaten importieren

train_data = pd.read_csv('../0_DataPreparation/data/train_data_new2.csv')

validation_data = pd.read_csv('../0_DataPreparation/data/validation_data_new2.csv')

test_data = pd.read_csv('../0_DataPreparation/data/test_data_new2.csv') 

# Nach NA Werten in den Testdaten schauen

test_data.isna().sum().sort_values(ascending=False).head(20)
#test_data['WettercodeKlar'].dtype
#test_data['KielerWoche'].dtype
#test_data['Fastenzeit'].dtype
# Out:
# Umsatz                            9482
# Windgeschwindigkeit                325
# id                                   0
# Datum                                0
# Temperatur                           0
# KielerWoche                          0
# WettercodeDunst                      0
# WettercodeExtremwetter               0
# WettercodeKlar                       0
# WettercodeNachSchlechtemWetter       0
# WettercodeNebel                      0
# WettercodeRegen                      0
# WettercodeSchnee                     0
# WarengruppeBread                     0
# WarengruppeRolls                     0
# WarengruppeCroissants                0
# WarengruppeConfectionery             0
# WarengruppeCake                      0
# WarengruppeSeasonalBread             0
# WochentagFreitag                     0
# dtype: int64

# %% [markdown]
# #### r^2 berechnen
#
# rse = sum (errors^2)/sum((actual-mean(actual))^2)
# r^2 = 1-rse

# %%
## alle Variablen im Modell drin außer Windgeschwindigkeit und Fastzeit
### Problem: Kaggle erwartet beim hochladen der Predictions genau 1830 Zeilen, wenn wir Zeilen im Test Data Bereich rausschneiden gibt es Probleme

# Modell trainieren ohne 
mod = smf.ols('Umsatz ~ Temperatur  + KielerWoche + NiederschlagTagessummeInMM + WettercodeDurchgehenderLeichterRegen + WettercodeDurchgehenderLeichterSchneefall + WettercodeDurchgehenderMaessigerRegen + WettercodeDurchgehenderMaeßigerSchneefall + WettercodeDurchgehenderStarkerRegen + WettercodeFeuchterDunst + WettercodeGewitter + WettercodeKlar + WettercodeNebel + WettercodeNebelAufgehoert + WettercodeNebelUndReifansatz + WettercodeRegenAufgehoert + WettercodeSchneeAufgehoert + WettercodeSchneegriesel + WettercodeSonstige + WettercodeSpruehregenOderSchneegrieselAufgehoert + WettercodeTrockenerDunst + WettercodeandauernderSpruehregen + WarengruppeBread + WarengruppeRolls + WarengruppeCroissants + WarengruppeConfectionery + WarengruppeCake + WarengruppeSeasonalBread + WochentagMontag + WochentagDienstag + WochentagMittwoch + WochentagDonnerstag + WochentagFreitag + WochentagSamstag + WochentagSonntag + Januar + Februar + Maerz + April + Mai + Juni + Juli + August + September + Oktober + November + Dezember + Bewoelkung0von0Klar + Bewoelkung1von8FastWolkenlos + Bewoelkung2von8 + Bewoelkung3von8 + Bewoelkung4von8 + Bewoelkung5von8 + Bewoelkung6von8 + Bewoelkung7von8 + Bewoelkung8von8Bedeckt + FeiertagKeiner + FeiertagChristiHimmelfahrt + FeiertagErsterMai + FeiertagHeiligabend + FeiertagOstermontag + FeiertagPfingstmontag + FeiertagSilvester + FeiertagTagDerDeutschenEinheit',
               data=train_data).fit()
print(mod.summary()) 

# Vorhersagen machen
test_data['Umsatz_Vorhersage'] = mod.predict(test_data)

# Nur ID und Umsatz_Vorhersage speichern
predictions_output = test_data[['id', 'Umsatz_Vorhersage']]
predictions_output.to_csv('../0_DataPreparation/data/predictions_preencoded_imputated.csv', index=False)


# Erste Vorhersagen anzeigen
print("\nErste 10 Vorhersagen:")
print(predictions_output.head(10))

#print("Warengruppe Dummy-Spalten:", warengruppe_cols)
#print("Wetter Dummy-Spalten:", wetter_cols)
#print("Bewoelkung Dummy-Spalten:", bewoelkung_cols)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/compat.py:40, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      39 try:
# ---> 40     return f(*args, **kwargs)
#      41 except Exception as e:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/eval.py:179, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     178 code = compile(expr, source_name, "eval", self.flags, False)
# --> 179 return eval(code, {}, VarLookupDict([inner_namespace] + self._namespaces))
#
# File <string>:1
#
# NameError: name 'WettercodeDurchgehenderLeichterSchneefall' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# Cell In[8], line 5
#       1 ## alle Variablen im Modell drin außer Windgeschwindigkeit und Fastzeit
#       2 ### Problem: Kaggle erwartet beim hochladen der Predictions genau 1830 Zeilen, wenn wir Zeilen im Test Data Bereich rausschneiden gibt es Probleme
#       3
#       4 # Modell trainieren ohne
# ----> 5 mod = smf.ols('Umsatz ~ Temperatur  + KielerWoche + NiederschlagTagessummeInMM + WettercodeDurchgehenderLeichterRegen + WettercodeDurchgehenderLeichterSchneefall + WettercodeDurchgehenderMaessigerRegen + WettercodeDurchgehenderMaeßigerSchneefall + WettercodeDurchgehenderStarkerRegen + WettercodeFeuchterDunst + WettercodeGewitter + WettercodeKlar + WettercodeNebel + WettercodeNebelAufgehoert + WettercodeNebelUndReifansatz + WettercodeRegenAufgehoert + WettercodeSchneeAufgehoert + WettercodeSchneegriesel + WettercodeSonstige + WettercodeSpruehregenOderSchneegrieselAufgehoert + WettercodeTrockenerDunst + WettercodeandauernderSpruehregen + WarengruppeBread + WarengruppeRolls + WarengruppeCroissants + WarengruppeConfectionery + WarengruppeCake + WarengruppeSeasonalBread + WochentagMontag + WochentagDienstag + WochentagMittwoch + WochentagDonnerstag + WochentagFreitag + WochentagSamstag + WochentagSonntag + Januar + Februar + Maerz + April + Mai + Juni + Juli + August + September + Oktober + November + Dezember + Bewoelkung0von0Klar + Bewoelkung1von8FastWolkenlos + Bewoelkung2von8 + Bewoelkung3von8 + Bewoelkung4von8 + Bewoelkung5von8 + Bewoelkung6von8 + Bewoelkung7von8 + Bewoelkung8von8Bedeckt + FeiertagKeiner + FeiertagChristiHimmelfahrt + FeiertagErsterMai + FeiertagHeiligabend + FeiertagOstermontag + FeiertagPfingstmontag + FeiertagSilvester + FeiertagTagDerDeutschenEinheit',
#       6                data=train_data).fit()
#       7 print(mod.summary())
#       9 # Vorhersagen machen
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/statsmodels/base/model.py:203, in Model.from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     200 if missing == 'none':  # with patsy it's drop or raise. let's raise.
#     201     missing = 'raise'
# --> 203 tmp = handle_formula_data(data, None, formula, depth=eval_env,
#     204                           missing=missing)
#     205 ((endog, exog), missing_idx, design_info) = tmp
#     206 max_endog = cls._formula_max_endog
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/statsmodels/formula/formulatools.py:63, in handle_formula_data(Y, X, formula, depth, missing)
#      61 else:
#      62     if data_util._is_using_pandas(Y, None):
# ---> 63         result = dmatrices(formula, Y, depth, return_type='dataframe',
#      64                            NA_action=na_action)
#      65     else:
#      66         result = dmatrices(formula, Y, depth, return_type='dataframe',
#      67                            NA_action=na_action)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/highlevel.py:317, in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     307 """Construct two design matrices given a formula_like and data.
#     308
#     309 This function is identical to :func:`dmatrix`, except that it requires
#    (...)    314 See :func:`dmatrix` for details.
#     315 """
#     316 eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 317 (lhs, rhs) = _do_highlevel_design(
#     318     formula_like, data, eval_env, NA_action, return_type
#     319 )
#     320 if lhs.shape[1] == 0:
#     321     raise PatsyError("model is missing required outcome variables")
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/highlevel.py:162, in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     159 def data_iter_maker():
#     160     return iter([data])
# --> 162 design_infos = _try_incr_builders(
#     163     formula_like, data_iter_maker, eval_env, NA_action
#     164 )
#     165 if design_infos is not None:
#     166     return build_design_matrices(
#     167         design_infos, data, NA_action=NA_action, return_type=return_type
#     168     )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/highlevel.py:56, in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      54 if isinstance(formula_like, ModelDesc):
#      55     assert isinstance(eval_env, EvalEnvironment)
# ---> 56     return design_matrix_builders(
#      57         [formula_like.lhs_termlist, formula_like.rhs_termlist],
#      58         data_iter_maker,
#      59         eval_env,
#      60         NA_action,
#      61     )
#      62 else:
#      63     return None
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/build.py:746, in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     743 factor_states = _factors_memorize(all_factors, data_iter_maker, eval_env)
#     744 # Now all the factors have working eval methods, so we can evaluate them
#     745 # on some data to find out what type of data they return.
# --> 746 (num_column_counts, cat_levels_contrasts) = _examine_factor_types(
#     747     all_factors, factor_states, data_iter_maker, NA_action
#     748 )
#     749 # Now we need the factor infos, which encapsulate the knowledge of
#     750 # how to turn any given factor into a chunk of data:
#     751 factor_infos = {}
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/build.py:491, in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     489 for data in data_iter_maker():
#     490     for factor in list(examine_needed):
# --> 491         value = factor.eval(factor_states[factor], data)
#     492         if factor in cat_sniffers or guess_categorical(value):
#     493             if factor not in cat_sniffers:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/eval.py:599, in EvalFactor.eval(self, memorize_state, data)
#     598 def eval(self, memorize_state, data):
# --> 599     return self._eval(memorize_state["eval_code"], memorize_state, data)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/eval.py:582, in EvalFactor._eval(self, code, memorize_state, data)
#     580 def _eval(self, code, memorize_state, data):
#     581     inner_namespace = VarLookupDict([data, memorize_state["transforms"]])
# --> 582     return call_and_wrap_exc(
#     583         "Error evaluating factor",
#     584         self,
#     585         memorize_state["eval_env"].eval,
#     586         code,
#     587         inner_namespace=inner_namespace,
#     588     )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/compat.py:43, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      41 except Exception as e:
#      42     new_exc = PatsyError("%s: %s: %s" % (msg, e.__class__.__name__, e), origin)
# ---> 43     raise new_exc from e
#
# PatsyError: Error evaluating factor: NameError: name 'WettercodeDurchgehenderLeichterSchneefall' is not defined
#     Umsatz ~ Temperatur  + KielerWoche + NiederschlagTagessummeInMM + WettercodeDurchgehenderLeichterRegen + WettercodeDurchgehenderLeichterSchneefall + WettercodeDurchgehenderMaessigerRegen + WettercodeDurchgehenderMaeßigerSchneefall + WettercodeDurchgehenderStarkerRegen + WettercodeFeuchterDunst + WettercodeGewitter + WettercodeKlar + WettercodeNebel + WettercodeNebelAufgehoert + WettercodeNebelUndReifansatz + WettercodeRegenAufgehoert + WettercodeSchneeAufgehoert + WettercodeSchneegriesel + WettercodeSonstige + WettercodeSpruehregenOderSchneegrieselAufgehoert + WettercodeTrockenerDunst + WettercodeandauernderSpruehregen + WarengruppeBread + WarengruppeRolls + WarengruppeCroissants + WarengruppeConfectionery + WarengruppeCake + WarengruppeSeasonalBread + WochentagMontag + WochentagDienstag + WochentagMittwoch + WochentagDonnerstag + WochentagFreitag + WochentagSamstag + WochentagSonntag + Januar + Februar + Maerz + April + Mai + Juni + Juli + August + September + Oktober + November + Dezember + Bewoelkung0von0Klar + Bewoelkung1von8FastWolkenlos + Bewoelkung2von8 + Bewoelkung3von8 + Bewoelkung4von8 + Bewoelkung5von8 + Bewoelkung6von8 + Bewoelkung7von8 + Bewoelkung8von8Bedeckt + FeiertagKeiner + FeiertagChristiHimmelfahrt + FeiertagErsterMai + FeiertagHeiligabend + FeiertagOstermontag + FeiertagPfingstmontag + FeiertagSilvester + FeiertagTagDerDeutschenEinheit
#                                                                                                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# %%
#train_data['Datum_ordinal'] = pd.to_datetime(train_data['Datum']).map(pd.Timestamp.toordinal)
#validation_data['Datum_ordinal'] = pd.to_datetime(validation_data['Datum']).map(pd.Timestamp.toordinal)
#test_data['Datum_ordinal'] = pd.to_datetime(test_data['Datum']).map(pd.Timestamp.toordinal)

# %%
# Modell trainieren ohne Windgeschwindigkeit und Fastzeit mit Daten von df_final_new.csv
# FeiertagSilvester FeiertagHeiligabend Datum WettercodeDunst Fastenzeit

mod = smf.ols('Umsatz ~ + Temperatur + KielerWoche + WettercodeExtremwetter + WettercodeKlar + WettercodeNachSchlechtemWetter + WettercodeNebel + WettercodeRegen + WettercodeSchnee + WarengruppeBread + WarengruppeRolls + WarengruppeConfectionery + WarengruppeCake + WarengruppeSeasonalBread + WochentagFreitag + WochentagSamstag + WochentagSonntag + WochentagUnterDerWoche + Januar + Maerz + April + Mai + Juni + Juli + August + September + Oktober + November + Dezember + BewoelkungWolkenBedeckt + BewoelkungWolkenBewoelkt + BewoelkungWolkenKlar + FeiertagChristiHimmelfahrt + FeiertagErsterMai + FeiertagPfingstmontag + FeiertagTagDerDeutschenEinheit + FeiertagSilvester + FeiertagHeiligabend',
               data=train_data).fit()
print(mod.summary())

validation_data['Umsatz_Pred'] = mod.predict(validation_data)

rmse_val = np.sqrt(mean_squared_error(
    validation_data['Umsatz'],
    validation_data['Umsatz_Pred']
))

print(f"Validation RMSE: {rmse_val:.2f}")

# Test-/Vorhersagedaten laden (die 1830 Zeilen ohne Umsatz)
test_data = pd.read_csv('../0_DataPreparation/data/test_data.csv')  

# Vorhersagen machen
test_data['Umsatz_Vorhersage'] = mod.predict(test_data)

# Nur ID und Umsatz_Vorhersage speichern
predictions_output = test_data[['id', 'Umsatz_Vorhersage']]
predictions_output.to_csv('../0_DataPreparation/data/predictions_preencoded_imputated.csv', index=False)


# Erste Vorhersagen anzeigen
print("\nErste 10 Vorhersagen:")
print(predictions_output.head(10))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Umsatz   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                 1.868e+04
# Date:                Sun, 04 Jan 2026   Prob (F-statistic):               0.00
# Time:                        17:09:23   Log-Likelihood:            -1.1356e+06
# No. Observations:              200297   AIC:                         2.271e+06
# Df Residuals:                  200261   BIC:                         2.272e+06
# Df Model:                          35
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         98.7810      0.487    203.005      0.000      97.827      99.735
# Temperatur                         0.3525      0.050      7.022      0.000       0.254       0.451
# KielerWoche                       39.6972      1.279     31.046      0.000      37.191      42.203
# WettercodeExtremwetter            -7.4775      1.344     -5.565      0.000     -10.111      -4.844
# WettercodeKlar                    -3.4009      0.606     -5.613      0.000      -4.589      -2.213
# WettercodeNachSchlechtemWetter    -4.7013      0.511     -9.207      0.000      -5.702      -3.700
# WettercodeNebel                  -13.9384      1.235    -11.289      0.000     -16.358     -11.519
# WettercodeRegen                   -5.3762      0.434    -12.382      0.000      -6.227      -4.525
# WettercodeSchnee                  -8.2147      1.421     -5.779      0.000     -11.001      -5.429
# WarengruppeBread                 -40.5109      0.505    -80.231      0.000     -41.501     -39.521
# WarengruppeRolls                 243.9003      0.505    483.040      0.000     242.911     244.890
# WarengruppeConfectionery         -72.3599      0.508   -142.356      0.000     -73.356     -71.364
# WarengruppeCake                  116.0149      0.505    229.765      0.000     115.025     117.005
# WarengruppeSeasonalBread         -61.8311      0.895    -69.056      0.000     -63.586     -60.076
# WochentagFreitag                   2.9701      0.377      7.884      0.000       2.232       3.709
# WochentagSamstag                  44.3098      0.376    117.999      0.000      43.574      45.046
# WochentagSonntag                  55.5612      0.373    148.866      0.000      54.830      56.293
# WochentagUnterDerWoche            -4.0602      0.251    -16.172      0.000      -4.552      -3.568
# Januar                           -17.0808      0.824    -20.728      0.000     -18.696     -15.466
# Maerz                            -11.3431      0.838    -13.529      0.000     -12.986      -9.700
# April                              6.8885      0.878      7.841      0.000       5.167       8.610
# Mai                               10.8122      0.992     10.896      0.000       8.867      12.757
# Juni                              15.1727      1.132     13.399      0.000      12.953      17.392
# Juli                              66.8719      1.112     60.147      0.000      64.693      69.051
# August                            96.5570      1.122     86.044      0.000      94.358      98.756
# September                         18.0825      1.039     17.400      0.000      16.046      20.119
# Oktober                           18.2532      0.898     20.324      0.000      16.493      20.013
# November                         -16.9257      0.765    -22.124      0.000     -18.425     -15.426
# Dezember                         -16.7187      0.781    -21.408      0.000     -18.249     -15.188
# BewoelkungWolkenBedeckt           31.7679      0.454     69.918      0.000      30.877      32.658
# BewoelkungWolkenBewoelkt          31.0451      0.296    104.886      0.000      30.465      31.625
# BewoelkungWolkenKlar              35.9680      0.356    101.027      0.000      35.270      36.666
# FeiertagChristiHimmelfahrt        65.5149      3.200     20.473      0.000      59.243      71.787
# FeiertagErsterMai                  9.7783      6.326      1.546      0.122      -2.621      22.178
# FeiertagPfingstmontag            117.1476      3.176     36.887      0.000     110.923     123.372
# FeiertagTagDerDeutschenEinheit    54.7891      3.194     17.151      0.000      48.528      61.050
# FeiertagSilvester                435.1128      3.648    119.262      0.000     427.962     442.264
# FeiertagHeiligabend               45.0724      2.772     16.259      0.000      39.639      50.506
# ==============================================================================
# Omnibus:                   129121.033   Durbin-Watson:                   0.077
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          8421789.785
# Skew:                           2.387   Prob(JB):                         0.00
# Kurtosis:                      34.406   Cond. No.                     6.81e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.06e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Validation RMSE: 67.29
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/compat.py:40, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      39 try:
# ---> 40     return f(*args, **kwargs)
#      41 except Exception as e:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/eval.py:179, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     178 code = compile(expr, source_name, "eval", self.flags, False)
# --> 179 return eval(code, {}, VarLookupDict([inner_namespace] + self._namespaces))
#
# File <string>:1
#
# NameError: name 'FeiertagSilvester' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/statsmodels/base/model.py:1102, in Results._transform_predict_exog(self, exog, transform)
#    1101 try:
# -> 1102     exog = dmatrix(design_info, exog, return_type="dataframe")
#    1103 except Exception as exc:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/highlevel.py:294, in dmatrix(formula_like, data, eval_env, NA_action, return_type)
#     293 eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 294 (lhs, rhs) = _do_highlevel_design(
#     295     formula_like, data, eval_env, NA_action, return_type
#     296 )
#     297 if lhs.shape[1] != 0:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/highlevel.py:166, in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     165 if design_infos is not None:
# --> 166     return build_design_matrices(
#     167         design_infos, data, NA_action=NA_action, return_type=return_type
#     168     )
#     169 else:
#     170     # No builders, but maybe we can still get matrices
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/build.py:952, in build_design_matrices(design_infos, data, NA_action, return_type, dtype)
#     951 if factor_info not in factor_info_to_values:
# --> 952     value, is_NA = _eval_factor(factor_info, data, NA_action)
#     953     factor_info_to_isNAs[factor_info] = is_NA
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/build.py:68, in _eval_factor(factor_info, data, NA_action)
#      67 factor = factor_info.factor
# ---> 68 result = factor.eval(factor_info.state, data)
#      69 # Returns either a 2d ndarray, or a DataFrame, plus is_NA mask
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/eval.py:599, in EvalFactor.eval(self, memorize_state, data)
#     598 def eval(self, memorize_state, data):
# --> 599     return self._eval(memorize_state["eval_code"], memorize_state, data)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/eval.py:582, in EvalFactor._eval(self, code, memorize_state, data)
#     581 inner_namespace = VarLookupDict([data, memorize_state["transforms"]])
# --> 582 return call_and_wrap_exc(
#     583     "Error evaluating factor",
#     584     self,
#     585     memorize_state["eval_env"].eval,
#     586     code,
#     587     inner_namespace=inner_namespace,
#     588 )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/compat.py:43, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      42 new_exc = PatsyError("%s: %s: %s" % (msg, e.__class__.__name__, e), origin)
# ---> 43 raise new_exc from e
#
# PatsyError: Error evaluating factor: NameError: name 'FeiertagSilvester' is not defined
#     Umsatz ~ + Temperatur + KielerWoche + WettercodeExtremwetter + WettercodeKlar + WettercodeNachSchlechtemWetter + WettercodeNebel + WettercodeRegen + WettercodeSchnee + WarengruppeBread + WarengruppeRolls + WarengruppeConfectionery + WarengruppeCake + WarengruppeSeasonalBread + WochentagFreitag + WochentagSamstag + WochentagSonntag + WochentagUnterDerWoche + Januar + Maerz + April + Mai + Juni + Juli + August + September + Oktober + November + Dezember + BewoelkungWolkenBedeckt + BewoelkungWolkenBewoelkt + BewoelkungWolkenKlar + FeiertagChristiHimmelfahrt + FeiertagErsterMai + FeiertagPfingstmontag + FeiertagTagDerDeutschenEinheit + FeiertagSilvester + FeiertagHeiligabend
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ^^^^^^^^^^^^^^^^^
#
# During handling of the above exception, another exception occurred:
#
# PatsyError                                Traceback (most recent call last)
# Cell In[5], line 21
#      18 test_data = pd.read_csv('../0_DataPreparation/data/test_data.csv')
#      20 # Vorhersagen machen
# ---> 21 test_data['Umsatz_Vorhersage'] = mod.predict(test_data)
#      23 # Nur ID und Umsatz_Vorhersage speichern
#      24 predictions_output = test_data[['id', 'Umsatz_Vorhersage']]
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/statsmodels/base/model.py:1171, in Results.predict(self, exog, transform, *args, **kwargs)
#    1126 def predict(self, exog=None, transform=True, *args, **kwargs):
#    1127     """
#    1128     Call self.model.predict with self.params as the first argument.
#    1129
#    (...)   1169     returned prediction.
#    1170     """
# -> 1171     exog, exog_index = self._transform_predict_exog(exog,
#    1172                                                     transform=transform)
#    1174     predict_results = self.model.predict(self.params, exog, *args,
#    1175                                          **kwargs)
#    1177     if exog_index is not None and not hasattr(predict_results,
#    1178                                               'predicted_values'):
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/statsmodels/base/model.py:1109, in Results._transform_predict_exog(self, exog, transform)
#    1103 except Exception as exc:
#    1104     msg = ('predict requires that you use a DataFrame when '
#    1105            'predicting from a model\nthat was created using the '
#    1106            'formula api.'
#    1107            '\n\nThe original error message returned by patsy is:\n'
#    1108            '{}'.format(str(str(exc))))
# -> 1109     raise exc.__class__(msg)
#    1110 if orig_exog_len > len(exog) and not is_dict:
#    1111     if exog_index is None:
#
# PatsyError: predict requires that you use a DataFrame when predicting from a model
# that was created using the formula api.
#
# The original error message returned by patsy is:
# Error evaluating factor: NameError: name 'FeiertagSilvester' is not defined
#     Umsatz ~ + Temperatur + KielerWoche + WettercodeExtremwetter + WettercodeKlar + WettercodeNachSchlechtemWetter + WettercodeNebel + WettercodeRegen + WettercodeSchnee + WarengruppeBread + WarengruppeRolls + WarengruppeConfectionery + WarengruppeCake + WarengruppeSeasonalBread + WochentagFreitag + WochentagSamstag + WochentagSonntag + WochentagUnterDerWoche + Januar + Maerz + April + Mai + Juni + Juli + August + September + Oktober + November + Dezember + BewoelkungWolkenBedeckt + BewoelkungWolkenBewoelkt + BewoelkungWolkenKlar + FeiertagChristiHimmelfahrt + FeiertagErsterMai + FeiertagPfingstmontag + FeiertagTagDerDeutschenEinheit + FeiertagSilvester + FeiertagHeiligabend
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ^^^^^^^^^^^^^^^^^
