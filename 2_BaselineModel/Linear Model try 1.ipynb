# %%
# %pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.14.5)
# Requirement already satisfied: numpy<3,>=1.22.3 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (2.3.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (1.16.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.formula.api as smf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Trainingsdaten laden
train_data = pd.read_csv('../0_DataPreparation/data/train_data.csv')

# Modell trainieren
mod = smf.ols('Umsatz ~ C(Warengruppe)', data=train_data).fit()
print(mod.summary())

# Test-/Vorhersagedaten laden (die 1830 Zeilen ohne Umsatz)
test_data = pd.read_csv('../0_DataPreparation/data/test_data.csv')  

# Vorhersagen machen
test_data['Umsatz_Vorhersage'] = mod.predict(test_data)

# Nur ID und Umsatz_Vorhersage speichern
predictions_output = test_data[['id', 'Umsatz_Vorhersage']]
predictions_output.to_csv('../0_DataPreparation/data/predictions.csv', index=False)

# Erste Vorhersagen anzeigen
print("\nErste 10 Vorhersagen:")
print(predictions_output.head(10))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Umsatz   R-squared:                       0.651
# Model:                            OLS   Adj. R-squared:                  0.650
# Method:                 Least Squares   F-statistic:                     2788.
# Date:                Thu, 27 Nov 2025   Prob (F-statistic):               0.00
# Time:                        16:26:40   Log-Likelihood:                -44125.
# No. Observations:                7493   AIC:                         8.826e+04
# Df Residuals:                    7487   BIC:                         8.830e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept             121.3353      2.285     53.094      0.000     116.855     125.815
# C(Warengruppe)[T.2]   289.2590      3.232     89.501      0.000     282.924     295.594
# C(Warengruppe)[T.3]    42.8076      3.232     13.245      0.000      36.472      49.143
# C(Warengruppe)[T.4]   -33.0088      3.262    -10.119      0.000     -39.404     -26.614
# C(Warengruppe)[T.5]   159.5546      3.232     49.369      0.000     153.219     165.890
# C(Warengruppe)[T.6]   -54.3611      6.130     -8.868      0.000     -66.378     -42.345
# ==============================================================================
# Omnibus:                     6535.130   Durbin-Watson:                   1.345
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           769298.986
# Skew:                           3.642   Prob(JB):                         0.00
# Kurtosis:                      52.102   Cond. No.                         7.24
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Erste 10 Vorhersagen:
#         id  Umsatz_Vorhersage
# 0  1808015         280.889924
# 1  1808012         410.594284
# 2  1808013         164.142961
# 3  1808014          88.326489
# 4  1808011         121.335322
# 5  1808023         164.142961
# 6  1808025         280.889924
# 7  1808022         410.594284
# 8  1808021         121.335322
# 9  1808024          88.326489

# %% [markdown]
# #### r^2 berechnen
#
# rse = sum (errors^2)/sum((actual-mean(actual))^2)
# r^2 = 1-rse

# %%
## mehrere Variablen

# Trainingsdaten laden
train_data = pd.read_csv('../0_DataPreparation/data/train_data.csv')


# Modell trainieren
mod = smf.ols('Umsatz ~ Temperatur + Windgeschwindigkeit + KielerWoche + Feiertage + WetterDurchgehenderLeichter_Regen + WetterDurchgehenderMässigerRegen + WetterDurchgehenderStarkerRegen + WetterDurchgehenderleichterSchneefall + WetterDurchgehendermaessigerSchneefall + WetterFeuchterDunst + WetterGewitter + WetterKlar + WetterNebel + WetterNebelReifansatz + WetterNebelaufgehoert + WetterRegenaufgehoert + Wetter_Schnee_aufgehoert + WetterSchneegriesel + WetterSonstige + WetterSpuehregenoderSchneegrieselaufgehoert + WetterTrockenerDunst + WetterandauernderSpruehregen + WarengruppeBread + WarengruppeRolls + WarengruppeCroissants + WarengruppeConfectionery + WarengruppeCake + WarengruppeSeasonalBread + Montag + Dienstag + Mittwoch + Donnerstag + Freitag + Samstag + Sonntag + Januar + Februar + Maerz + April + Mai + Juni + Juli + August + September + Oktober + November + Dezember + Bewoelkung08Klar + Bewoelkung18Fastwolkenlos + Bewoelkung28leichtbewoelkt + Bewoelkung38 + Bewoelkung48wolkig + Bewoelkung58 + Bewoelkung68starkbewoelkt + Bewoelkung78fastbedeckt + Bewoelkung88bedeckt',
               data=train_data).fit()
print(mod.summary())

# Test-/Vorhersagedaten laden (die 1830 Zeilen ohne Umsatz)
test_data = pd.read_csv('../0_DataPreparation/data/test_data.csv')  

# Vorhersagen machen
test_data['Umsatz_Vorhersage'] = mod.predict(test_data)

# Nur ID und Umsatz_Vorhersage speichern
predictions_output = test_data[['id', 'Umsatz_Vorhersage']]
predictions_output.to_csv('../0_DataPreparation/data/predictions_preencoded.csv', index=False)

# Erste Vorhersagen anzeigen
print("\nErste 10 Vorhersagen:")
print(predictions_output.head(10))

#print("Warengruppe Dummy-Spalten:", warengruppe_cols)
#print("Wetter Dummy-Spalten:", wetter_cols)
#print("Bewoelkung Dummy-Spalten:", bewoelkung_cols)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Umsatz   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.739
# Method:                 Least Squares   F-statistic:                     380.3
# Date:                Thu, 11 Dec 2025   Prob (F-statistic):               0.00
# Time:                        16:07:41   Log-Likelihood:                -42963.
# No. Observations:                7487   AIC:                         8.604e+04
# Df Residuals:                    7430   BIC:                         8.643e+04
# Df Model:                          56
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                     124.6144      3.285     37.940      0.000     118.176     131.053
# Feiertage[T.Christi Himmelfahrt]               62.5260     17.430      3.587      0.000      28.358      96.694
# Feiertage[T.Erster Mai]                        13.0648     34.123      0.383      0.702     -53.825      79.955
# Feiertage[T.Ostermontag]                       86.4571     17.263      5.008      0.000      52.617     120.297
# Feiertage[T.Pfingstmontag]                    116.8354     17.233      6.780      0.000      83.053     150.618
# Feiertage[T.Tag der Deutschen Einheit]         53.0270     17.274      3.070      0.002      19.165      86.889
# Temperatur                                      0.3158      0.295      1.069      0.285      -0.263       0.895
# Windgeschwindigkeit                             0.3075      0.227      1.352      0.176      -0.138       0.753
# KielerWoche                                    39.4968      6.863      5.755      0.000      26.043      52.951
# WetterDurchgehenderLeichter_Regen              -5.0995      3.007     -1.696      0.090     -10.994       0.795
# WetterDurchgehenderMässigerRegen               -5.2318      4.231     -1.237      0.216     -13.525       3.061
# WetterDurchgehenderStarkerRegen                -4.2190      8.105     -0.521      0.603     -20.107      11.669
# WetterDurchgehenderleichterSchneefall          -8.5689     13.067     -0.656      0.512     -34.185      17.047
# WetterDurchgehendermaessigerSchneefall        -33.0415     18.761     -1.761      0.078     -69.819       3.736
# WetterFeuchterDunst                            -0.5325      3.926     -0.136      0.892      -8.229       7.164
# WetterGewitter                                 -5.8514      7.577     -0.772      0.440     -20.705       9.002
# WetterKlar                                     -6.3749      3.525     -1.808      0.071     -13.285       0.535
# WetterNebel                                   -13.3990      8.930     -1.500      0.134     -30.905       4.107
# WetterNebelReifansatz                         -20.1794     12.096     -1.668      0.095     -43.892       3.533
# WetterNebelaufgehoert                          32.1665     10.326      3.115      0.002      11.925      52.408
# WetterRegenaufgehoert                          -6.0863      3.377     -1.802      0.072     -12.706       0.533
# Wetter_Schnee_aufgehoert                        0.7318     10.601      0.069      0.945     -20.049      21.512
# WetterSchneegriesel                            -0.8880     13.434     -0.066      0.947     -27.223      25.447
# WetterSonstige                                 -3.8027     12.234     -0.311      0.756     -27.785      20.180
# WetterSpuehregenoderSchneegrieselaufgehoert    -6.8297      5.902     -1.157      0.247     -18.399       4.739
# WetterTrockenerDunst                            1.0974      5.119      0.214      0.830      -8.938      11.133
# WetterandauernderSpruehregen                  -31.7195     15.122     -2.098      0.036     -61.363      -2.076
# WarengruppeBread                              -51.5068      2.015    -25.559      0.000     -55.457     -47.556
# WarengruppeRolls                              237.6571      2.015    117.930      0.000     233.707     241.607
# WarengruppeCroissants                          -8.7506      2.015     -4.342      0.000     -12.701      -4.800
# WarengruppeConfectionery                      -84.5134      2.043    -41.372      0.000     -88.518     -80.509
# WarengruppeCake                               108.0166      2.015     53.600      0.000     104.066     111.967
# WarengruppeSeasonalBread                      -76.2885      4.560    -16.729      0.000     -85.228     -67.349
# Montag                                          2.0209      2.222      0.910      0.363      -2.335       6.377
# Dienstag                                       -0.1377      2.199     -0.063      0.950      -4.448       4.173
# Mittwoch                                       -1.6018      2.190     -0.732      0.464      -5.894       2.691
# Donnerstag                                      4.6779      2.241      2.087      0.037       0.285       9.071
# Freitag                                         7.9998      2.225      3.595      0.000       3.637      12.362
# Samstag                                        52.7017      2.209     23.855      0.000      48.371      57.032
# Sonntag                                        58.9537      2.217     26.588      0.000      54.607      63.300
# Januar                                        -23.7416      3.854     -6.161      0.000     -31.296     -16.187
# Februar                                        -5.6208      3.587     -1.567      0.117     -12.653       1.411
# Maerz                                         -17.6521      3.163     -5.580      0.000     -23.853     -11.451
# April                                          -0.0178      3.107     -0.006      0.995      -6.108       6.072
# Mai                                             6.0085      3.289      1.827      0.068      -0.438      12.455
# Juni                                            9.6503      4.055      2.380      0.017       1.701      17.599
# Juli                                           63.3210      3.778     16.761      0.000      55.915      70.727
# August                                         91.8998      3.892     23.610      0.000      84.269      99.530
# September                                      13.7180      3.443      3.984      0.000       6.968      20.468
# Oktober                                        13.9380      3.003      4.641      0.000       8.051      19.825
# November                                      -20.8702      3.036     -6.874      0.000     -26.822     -14.919
# Dezember                                       -6.0185      3.325     -1.810      0.070     -12.537       0.500
# Bewoelkung08Klar                               15.1146      2.794      5.409      0.000       9.637      20.592
# Bewoelkung18Fastwolkenlos                      17.6039      3.564      4.939      0.000      10.617      24.591
# Bewoelkung28leichtbewoelkt                     13.6002      3.478      3.911      0.000       6.783      20.417
# Bewoelkung38                                   19.6939      3.245      6.069      0.000      13.332      26.055
# Bewoelkung48wolkig                             13.5928      3.021      4.499      0.000       7.670      19.515
# Bewoelkung58                                   12.9605      2.831      4.578      0.000       7.411      18.510
# Bewoelkung68starkbewoelkt                      12.9542      2.388      5.426      0.000       8.274      17.634
# Bewoelkung78fastbedeckt                        10.7041      2.075      5.157      0.000       6.636      14.773
# Bewoelkung88bedeckt                             8.3903      3.227      2.600      0.009       2.064      14.716
# ==============================================================================
# Omnibus:                     8293.565   Durbin-Watson:                   1.780
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2718652.030
# Skew:                           5.154   Prob(JB):                         0.00
# Kurtosis:                      95.782   Cond. No.                     6.09e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.16e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Erste 10 Vorhersagen:
#         id  Umsatz_Vorhersage
# 0  1808015         342.247431
# 1  1808012         471.887872
# 2  1808013         225.480247
# 3  1808014         149.717442
# 4  1808011         182.723980
# 5  1808023         232.525743
# 6  1808025         349.292927
# 7  1808022         478.933368
# 8  1808021         189.769476
# 9  1808024         156.762938
