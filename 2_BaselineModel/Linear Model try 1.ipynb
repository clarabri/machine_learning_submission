# %%
# %pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.14.5)
# Requirement already satisfied: numpy<3,>=1.22.3 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (2.3.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (1.16.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.formula.api as smf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Trainingsdaten laden
train_data = pd.read_csv('../0_DataPreparation/data/train_data.csv')

# Modell trainieren
mod = smf.ols('Umsatz ~ C(Warengruppe)', data=train_data).fit()
print(mod.summary())

# Test-/Vorhersagedaten laden (die 1830 Zeilen ohne Umsatz)
test_data = pd.read_csv('../0_DataPreparation/data/test_data.csv')  

# Vorhersagen machen
test_data['Umsatz_Vorhersage'] = mod.predict(test_data)

# Nur ID und Umsatz_Vorhersage speichern
predictions_output = test_data[['id', 'Umsatz_Vorhersage']]
predictions_output.to_csv('../0_DataPreparation/data/predictions.csv', index=False)

# Erste Vorhersagen anzeigen
print("\nErste 10 Vorhersagen:")
print(predictions_output.head(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/compat.py:40, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      39 try:
# ---> 40     return f(*args, **kwargs)
#      41 except Exception as e:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/eval.py:179, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     178 code = compile(expr, source_name, "eval", self.flags, False)
# --> 179 return eval(code, {}, VarLookupDict([inner_namespace] + self._namespaces))
#
# File <string>:1
#
# NameError: name 'Warengruppe' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# Cell In[3], line 5
#       2 train_data = pd.read_csv('../0_DataPreparation/data/train_data.csv')
#       4 # Modell trainieren
# ----> 5 mod = smf.ols('Umsatz ~ C(Warengruppe)', data=train_data).fit()
#       6 print(mod.summary())
#       8 # Test-/Vorhersagedaten laden (die 1830 Zeilen ohne Umsatz)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/statsmodels/base/model.py:203, in Model.from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     200 if missing == 'none':  # with patsy it's drop or raise. let's raise.
#     201     missing = 'raise'
# --> 203 tmp = handle_formula_data(data, None, formula, depth=eval_env,
#     204                           missing=missing)
#     205 ((endog, exog), missing_idx, design_info) = tmp
#     206 max_endog = cls._formula_max_endog
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/statsmodels/formula/formulatools.py:63, in handle_formula_data(Y, X, formula, depth, missing)
#      61 else:
#      62     if data_util._is_using_pandas(Y, None):
# ---> 63         result = dmatrices(formula, Y, depth, return_type='dataframe',
#      64                            NA_action=na_action)
#      65     else:
#      66         result = dmatrices(formula, Y, depth, return_type='dataframe',
#      67                            NA_action=na_action)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/highlevel.py:317, in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     307 """Construct two design matrices given a formula_like and data.
#     308
#     309 This function is identical to :func:`dmatrix`, except that it requires
#    (...)    314 See :func:`dmatrix` for details.
#     315 """
#     316 eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 317 (lhs, rhs) = _do_highlevel_design(
#     318     formula_like, data, eval_env, NA_action, return_type
#     319 )
#     320 if lhs.shape[1] == 0:
#     321     raise PatsyError("model is missing required outcome variables")
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/highlevel.py:162, in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     159 def data_iter_maker():
#     160     return iter([data])
# --> 162 design_infos = _try_incr_builders(
#     163     formula_like, data_iter_maker, eval_env, NA_action
#     164 )
#     165 if design_infos is not None:
#     166     return build_design_matrices(
#     167         design_infos, data, NA_action=NA_action, return_type=return_type
#     168     )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/highlevel.py:56, in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      54 if isinstance(formula_like, ModelDesc):
#      55     assert isinstance(eval_env, EvalEnvironment)
# ---> 56     return design_matrix_builders(
#      57         [formula_like.lhs_termlist, formula_like.rhs_termlist],
#      58         data_iter_maker,
#      59         eval_env,
#      60         NA_action,
#      61     )
#      62 else:
#      63     return None
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/build.py:746, in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     743 factor_states = _factors_memorize(all_factors, data_iter_maker, eval_env)
#     744 # Now all the factors have working eval methods, so we can evaluate them
#     745 # on some data to find out what type of data they return.
# --> 746 (num_column_counts, cat_levels_contrasts) = _examine_factor_types(
#     747     all_factors, factor_states, data_iter_maker, NA_action
#     748 )
#     749 # Now we need the factor infos, which encapsulate the knowledge of
#     750 # how to turn any given factor into a chunk of data:
#     751 factor_infos = {}
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/build.py:491, in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     489 for data in data_iter_maker():
#     490     for factor in list(examine_needed):
# --> 491         value = factor.eval(factor_states[factor], data)
#     492         if factor in cat_sniffers or guess_categorical(value):
#     493             if factor not in cat_sniffers:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/eval.py:599, in EvalFactor.eval(self, memorize_state, data)
#     598 def eval(self, memorize_state, data):
# --> 599     return self._eval(memorize_state["eval_code"], memorize_state, data)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/eval.py:582, in EvalFactor._eval(self, code, memorize_state, data)
#     580 def _eval(self, code, memorize_state, data):
#     581     inner_namespace = VarLookupDict([data, memorize_state["transforms"]])
# --> 582     return call_and_wrap_exc(
#     583         "Error evaluating factor",
#     584         self,
#     585         memorize_state["eval_env"].eval,
#     586         code,
#     587         inner_namespace=inner_namespace,
#     588     )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/patsy/compat.py:43, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      41 except Exception as e:
#      42     new_exc = PatsyError("%s: %s: %s" % (msg, e.__class__.__name__, e), origin)
# ---> 43     raise new_exc from e
#
# PatsyError: Error evaluating factor: NameError: name 'Warengruppe' is not defined
#     Umsatz ~ C(Warengruppe)
#              ^^^^^^^^^^^^^^

# %% [markdown]
# #### r^2 berechnen
#
# rse = sum (errors^2)/sum((actual-mean(actual))^2)
# r^2 = 1-rse

# %%
## mehrere Variablen
### Problem: Kaggle erwartet beim hochladen der Predictions genau 1830 Zeilen, wenn wir Zeilen im Test Data Bereich rausschneiden gibt es Probleme

# Trainingsdaten laden

train_data = pd.read_csv('../0_DataPreparation/data/train_data.csv')

# Modell trainieren
mod = smf.ols('Umsatz ~ Temperatur + Feiertage + Windgeschwindigkeit + KielerWoche + WettercodeDurchgehenderLeichterRegen + WettercodeDurchgehenderLeichterSchneefall + WettercodeDurchgehenderMaessigerRegen + WettercodeDurchgehenderMaeßigerSchneefall + WettercodeDurchgehenderStarkerRegen + WettercodeFeuchterDunst + WettercodeGewitter + WettercodeKlar + WettercodeNebel + WettercodeNebelAufgehoert + WettercodeNebelUndReifansatz + WettercodeRegenAufgehoert + WettercodeSchneeAufgehoert + WettercodeSchneegriesel + WettercodeSonstige + WettercodeSpruehregenOderSchneegrieselAufgehoert + WettercodeTrockenerDunst + WettercodeandauernderSpruehregen + WarengruppeBread + WarengruppeRolls + WarengruppeCroissants + WarengruppeConfectionery + WarengruppeCake + WarengruppeSeasonalBread + WochentagMontag + WochentagDienstag + WochentagMittwoch + WochentagDonnerstag + WochentagFreitag + WochentagSamstag + WochentagSonntag + MonatJanuar + MonatFebruar + MonatMaerz + MonatApril + MonatMai + MonatJuni + MonatJuli + MonatAugust + MonatSeptember + MonatOktober + MonatNovember + MonatDezember + BewoelkungKlar + Bewoelkung1von8FastWolkenlos + Bewoelkung2von8LeichtBewoelkt + Bewoelkung3von8 + Bewoelkung4von8Wolkig + Bewoelkung5von8 + Bewoelkung6von8StarkBewoelkt + Bewoelkung7von8FastBedeckt + Bewoelkung8von8Bedeckt',
               data=train_data).fit()
print(mod.summary())

# Test-/Vorhersagedaten laden (die 1830 Zeilen ohne Umsatz)
test_data = pd.read_csv('../0_DataPreparation/data/test_data.csv')  

# Vorhersagen machen
test_data['Umsatz_Vorhersage'] = mod.predict(test_data)

# Nur ID und Umsatz_Vorhersage speichern
predictions_output = test_data[['id', 'Umsatz_Vorhersage']]
predictions_output.to_csv('../0_DataPreparation/data/predictions_preencoded_imputated.csv', index=False)

# Erste Vorhersagen anzeigen
print("\nErste 10 Vorhersagen:")
print(predictions_output.head(10))

#print("Warengruppe Dummy-Spalten:", warengruppe_cols)
#print("Wetter Dummy-Spalten:", wetter_cols)
#print("Bewoelkung Dummy-Spalten:", bewoelkung_cols)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Umsatz   R-squared:                       0.738
# Model:                            OLS   Adj. R-squared:                  0.736
# Method:                 Least Squares   F-statistic:                     419.1
# Date:                Sun, 14 Dec 2025   Prob (F-statistic):               0.00
# Time:                        11:40:50   Log-Likelihood:                -43010.
# No. Observations:                7487   AIC:                         8.612e+04
# Df Residuals:                    7436   BIC:                         8.648e+04
# Df Model:                          50
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                          127.8207      2.882     44.353      0.000     122.171     133.470
# Temperatur                                           0.2675      0.296      0.903      0.367      -0.313       0.848
# KielerWoche                                         36.6053      6.890      5.313      0.000      23.099      50.112
# WettercodeDurchgehenderLeichterRegen                -4.1346      2.995     -1.381      0.167     -10.005       1.736
# WettercodeDurchgehenderLeichterSchneefall           -8.0069     13.141     -0.609      0.542     -33.768      17.754
# WettercodeDurchgehenderMaessigerRegen               -5.1196      4.219     -1.213      0.225     -13.391       3.152
# WettercodeDurchgehenderMaeßigerSchneefall          -29.9388     18.779     -1.594      0.111     -66.751       6.873
# WettercodeDurchgehenderStarkerRegen                 -4.9268      8.132     -0.606      0.545     -20.868      11.014
# WettercodeFeuchterDunst                             -0.8846      3.937     -0.225      0.822      -8.601       6.832
# WettercodeGewitter                                  -5.9161      7.613     -0.777      0.437     -20.841       9.008
# WettercodeKlar                                      -5.8258      3.536     -1.647      0.100     -12.758       1.106
# WettercodeNebel                                    -14.6157      8.957     -1.632      0.103     -32.174       2.943
# WettercodeNebelAufgehoert                           31.8176     10.367      3.069      0.002      11.494      52.141
# WettercodeNebelUndReifansatz                       -21.3295     12.127     -1.759      0.079     -45.103       2.444
# WettercodeRegenAufgehoert                           -6.4447      3.366     -1.915      0.056     -13.043       0.154
# WettercodeSchneeAufgehoert                           0.4925     10.654      0.046      0.963     -20.393      21.378
# WettercodeSchneegriesel                             -0.5476     13.506     -0.041      0.968     -27.024      25.929
# WettercodeSonstige                                  -4.2287     12.299     -0.344      0.731     -28.339      19.881
# WettercodeSpruehregenOderSchneegrieselAufgehoert    -5.6760      5.928     -0.958      0.338     -17.296       5.944
# WettercodeTrockenerDunst                             1.1514      5.115      0.225      0.822      -8.875      11.177
# WettercodeandauernderSpruehregen                   -32.2942     15.206     -2.124      0.034     -62.103      -2.485
# WarengruppeBread                                   -50.9695      2.010    -25.361      0.000     -54.909     -47.030
# WarengruppeRolls                                   238.1944      2.010    118.519      0.000     234.255     242.134
# WarengruppeCroissants                               -8.2132      2.010     -4.087      0.000     -12.153      -4.274
# WarengruppeConfectionery                           -83.9543      2.038    -41.196      0.000     -87.949     -79.959
# WarengruppeCake                                    108.5540      2.010     54.013      0.000     104.614     112.494
# WarengruppeSeasonalBread                           -75.7906      4.577    -16.557      0.000     -84.764     -66.817
# WochentagMontag                                      5.6869      2.183      2.605      0.009       1.408       9.966
# WochentagDienstag                                   -0.5211      2.196     -0.237      0.812      -4.826       3.783
# WochentagMittwoch                                   -2.0282      2.185     -0.928      0.353      -6.312       2.256
# WochentagDonnerstag                                  5.5791      2.224      2.508      0.012       1.219       9.939
# WochentagFreitag                                     7.8042      2.231      3.497      0.000       3.430      12.178
# WochentagSamstag                                    52.5931      2.209     23.807      0.000      48.263      56.924
# WochentagSonntag                                    58.7067      2.209     26.580      0.000      54.377      63.036
# MonatJanuar                                        -24.6162      3.864     -6.370      0.000     -32.191     -17.041
# MonatFebruar                                        -6.6280      3.598     -1.842      0.065     -13.681       0.425
# MonatMaerz                                         -17.5973      3.156     -5.575      0.000     -23.784     -11.410
# MonatApril                                           1.7986      3.067      0.586      0.558      -4.213       7.810
# MonatMai                                             9.8379      3.213      3.062      0.002       3.539      16.137
# MonatJuni                                           12.0251      4.053      2.967      0.003       4.080      19.970
# MonatJuli                                           62.9835      3.793     16.604      0.000      55.548      70.419
# MonatAugust                                         91.2941      3.910     23.349      0.000      83.629      98.959
# MonatSeptember                                      12.8329      3.459      3.710      0.000       6.052      19.614
# MonatOktober                                        14.7290      2.978      4.945      0.000       8.891      20.567
# MonatNovember                                      -22.0491      3.047     -7.235      0.000     -28.023     -16.075
# MonatDezember                                       -6.7898      3.337     -2.035      0.042     -13.331      -0.249
# BewoelkungKlar                                      16.0014      2.799      5.718      0.000      10.516      21.487
# Bewoelkung1von8FastWolkenlos                        18.2298      3.576      5.098      0.000      11.220      25.239
# Bewoelkung2von8LeichtBewoelkt                       14.1303      3.488      4.051      0.000       7.293      20.968
# Bewoelkung3von8                                     19.8023      3.254      6.086      0.000      13.424      26.180
# Bewoelkung4von8Wolkig                               14.5836      3.022      4.825      0.000       8.659      20.508
# Bewoelkung5von8                                     13.9052      2.814      4.941      0.000       8.388      19.422
# Bewoelkung6von8StarkBewoelkt                        13.2543      2.384      5.559      0.000       8.580      17.928
# Bewoelkung7von8FastBedeckt                          10.4994      2.085      5.036      0.000       6.413      14.586
# Bewoelkung8von8Bedeckt                               7.4145      3.240      2.288      0.022       1.062      13.767
# ==============================================================================
# Omnibus:                     8235.074   Durbin-Watson:                   1.756
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2584985.727
# Skew:                           5.102   Prob(JB):                         0.00
# Kurtosis:                      93.456   Cond. No.                     5.49e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.87e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Erste 10 Vorhersagen:
#         id  Umsatz_Vorhersage
# 0  1808015         342.171519
# 1  1808012         471.811960
# 2  1808013         225.404335
# 3  1808014         149.663218
# 4  1808011         182.648068
# 5  1808023         233.660252
# 6  1808025         350.427436
# 7  1808022         480.067877
# 8  1808021         190.903985
# 9  1808024         157.919135
