# %%
import pandas as pd
df_final = pd.read_csv('df_final.csv')
df_test = pd.read_csv('test_data.csv')
print('Spalten in Testdaten')
print(df_test.head())

print('Existiert FeiertagSilvester in test_data.csv?')
# summing up the boolean series to see if any True values exist
print(df_test['FeiertagSilvester'].sum() > 0)
print(df_test['FeiertagSilvester'])
# Out:
# Spalten in Testdaten
#         id       Datum  Umsatz  Temperatur  Windgeschwindigkeit  KielerWoche  \
# 0  1808015  2018-08-01     NaN     23.7625                 10.0          0.0
# 1  1808012  2018-08-01     NaN     23.7625                 10.0          0.0
# 2  1808013  2018-08-01     NaN     23.7625                 10.0          0.0
# 3  1808014  2018-08-01     NaN     23.7625                 10.0          0.0
# 4  1808011  2018-08-01     NaN     23.7625                 10.0          0.0
#
#    WettercodeDunst  WettercodeExtremwetter  WettercodeKlar  \
# 0                0                       0               1
# 1                0                       0               1
# 2                0                       0               1
# 3                0                       0               1
# 4                0                       0               1
#
#    WettercodeNachSchlechtemWetter  ...  BewoelkungWolkenKlar  \
# ...
